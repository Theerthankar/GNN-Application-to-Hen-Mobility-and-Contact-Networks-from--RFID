# %% [markdown]
# # Load & Clean Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# List files/folders in your Google Drive
print(os.listdir('/content/drive/MyDrive/Hens Mobility/data'))
# Out:
# ['combined_all_data.csv', 'cleaned_combined_data.csv', 'hen_contact_graph.gexf']

# %%
data_path = '/content/drive/MyDrive/Hens Mobility/data/combined_all_data.csv'

# %%
data_path
# Out:
# '/content/drive/MyDrive/Hens Mobility/data/combined_all_data.csv'

# %% [markdown]
# # Data

# %%
import pandas as pd

df = pd.read_csv(data_path)

# %%
df
# Out:
#                     V1            V2     V3            V4            V5  \
# 0         CA0000001770  CA0000001582   98.0  P3:EE:H4:A11  1.488202e+09
# 1         CA0000001601  CA0000001582  167.0  P3:EE:H4:A11  1.488202e+09
# 2         CA0000001601  CA0000001770  150.0  P3:EE:H4:A11  1.488202e+09
# 3         CA0000001601  CA0000000630   68.0  P3:EE:H4:A11  1.488202e+09
# 4         CA0000001655  CA0000001582   35.0  P3:EE:H4:A11  1.488202e+09
# ...                ...           ...    ...           ...           ...
# 25195579  CA0000001783  CA0000001221  141.0   P3:EB:H1:A6  1.491731e+09
# 25195580  CA0000002033  CA0000010434   43.0   P3:EB:H1:A6  1.491745e+09
# 25195581  CA0000002033  CA0000001221  141.0   P3:EB:H1:A6  1.491745e+09
# 25195582  CA0000002033  CA0000001783  754.0   P3:EB:H1:A6  1.491745e+09
# 25195583  CA0000002033  CA0000001221  341.0   P3:EB:H1:A6  1.491745e+09
#
#                     V6            V7            V8          time  \
# 0         1.488202e+09  1.488202e+09  1.488202e+09  1.488202e+09
# 1         1.488202e+09  1.488202e+09  1.488202e+09  1.488202e+09
# 2         1.488202e+09  1.488202e+09  1.488202e+09  1.488202e+09
# 3         1.488202e+09  1.488202e+09  1.488202e+09  1.488202e+09
# 4         1.488202e+09  1.488202e+09  1.488202e+09  1.488202e+09
# ...                ...           ...           ...           ...
# 25195579  1.491746e+09  1.491746e+09  1.491746e+09  1.491742e+09
# 25195580  1.491730e+09  1.491746e+09  1.491745e+09  1.491742e+09
# 25195581  1.491746e+09  1.491746e+09  1.491746e+09  1.491746e+09
# 25195582  1.491731e+09  1.491746e+09  1.491746e+09  1.491742e+09
# 25195583  1.491746e+09  1.491746e+09  1.491746e+09  1.491746e+09
#
#                            time_        date                    source_file
# 0            2017-02-27 03:25:16  2017-02-27  14 2017-02-27 matrix2_res.csv
# 1         2017-02-27 03:25:30.25  2017-02-27  14 2017-02-27 matrix2_res.csv
# 2         2017-02-27 03:26:42.75  2017-02-27  14 2017-02-27 matrix2_res.csv
# 3         2017-02-27 03:27:44.25  2017-02-27  14 2017-02-27 matrix2_res.csv
# 4          2017-02-27 03:26:36.5  2017-02-27  14 2017-02-27 matrix2_res.csv
# ...                          ...         ...                            ...
# 25195579  2017-04-09 02:48:07.25  2017-04-09  54 2017-04-08 matrix2_res.csv
# 25195580  2017-04-09 02:40:50.25  2017-04-09  54 2017-04-08 matrix2_res.csv
# 25195581  2017-04-09 03:50:15.75  2017-04-09  54 2017-04-08 matrix2_res.csv
# 25195582     2017-04-09 02:48:25  2017-04-09  54 2017-04-08 matrix2_res.csv
# 25195583  2017-04-09 03:53:45.75  2017-04-09  54 2017-04-08 matrix2_res.csv
#
# [25195584 rows x 12 columns]

# %% [markdown]
# - V1, V2: IDs (hen IDs / tag IDs)
# - V3, V4: Possibly some measurement/metadata
# - V5-V8: Numeric, likely timestamp-related
# - time, time_: human-readable timestamp
# - date: date
# - source_file: which file it came from

# %%
print("\nData types:\n", df.dtypes)
# Out:
# Data types:
#  V1              object
# V2              object
# V3             float64
# V4              object
# V5             float64
# V6             float64
# V7             float64
# V8             float64
# time           float64
# time_           object
# date            object
# source_file     object
# dtype: object

# %%
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  V1             3
# V2             3
# V3             3
# V4             3
# V5             3
# V6             3
# V7             3
# V8             3
# time           3
# time_          3
# date           3
# source_file    0
# dtype: int64

# %%
print("Befor removing null values & parse timestamp,data:", df.shape)
# Out:
# Befor: (25195584, 12)

# %% [markdown]
# # Dropping missing values & Parse timestamps,date

# %%
import pandas as pd

# %%
chunk_size = 1_000_000  # 1 million rows at a time
cleaned_chunks = []

# %%
for chunk in pd.read_csv(data_path, chunksize=chunk_size):

    # Drop rows with any missing values
    chunk = chunk.dropna()

    # Convert timestamps with fractional seconds parsing
    #chunk.loc[:, 'time'] = pd.to_datetime(chunk['time'], format='%Y-%m-%d %H:%M:%S.%f', errors='coerce')
    #chunk.loc[:, 'time_'] = pd.to_datetime(chunk['time_'], format='%Y-%m-%d %H:%M:%S.%f', errors='coerce')

    # Drop rows where timestamp parsing failed
    #chunk = chunk.dropna(subset=['time', 'time_'])

    # Append cleaned chunk to list
    cleaned_chunks.append(chunk)

    print("Processed chunk, current rows:", chunk.shape[0])
# Out:
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 999999
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 999999
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 999999
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 1000000
# Processed chunk, current rows: 195584

# %%
# Combine cleaned chunks
df_clean = pd.concat(cleaned_chunks, ignore_index=True)
print("\nAfter removing null values", df_clean.shape)
# Out:
# After removing null values (25195581, 12)

# %%
print("\nMissing values:\n", df_clean.isnull().sum())
# Out:
# Missing values:
#  V1             0
# V2             0
# V3             0
# V4             0
# V5             0
# V6             0
# V7             0
# V8             0
# time           0
# time_          0
# date           0
# source_file    0
# dtype: int64

# %%
print("\nData types:\n", df_clean.dtypes)
# Out:
# Data types:
#  V1              object
# V2              object
# V3             float64
# V4              object
# V5             float64
# V6             float64
# V7             float64
# V8             float64
# time           float64
# time_           object
# date            object
# source_file     object
# dtype: object

# %%
# Drop rows where timestamp parsing failed (ensures valid timestamps only)
#df_clean = df_clean.dropna(subset=['time', 'time_'])
#print("After dropping rows with invalid timestamps:", df_clean.shape)

# %%
# Drop any remaining rows with missing values in other columns (if needed)
#df_clean = df_clean.dropna()
#print("Final cleaned shape:", df_clean.shape)

# %%
# Let pandas infer the format
df_clean['time'] = pd.to_datetime(df_clean['time'], errors='coerce')
df_clean['time_'] = pd.to_datetime(df_clean['time_'], errors='coerce')

# Drop rows where parsing failed
df_clean = df_clean.dropna(subset=['time', 'time_'])
print("After Timestamps parsed -  Final shape:", df_clean.shape)
# Out:
# After Timestamps parsed -  Final shape: (6298014, 12)

# %%
print("\nData types:\n", df_clean.dtypes)
# Out:
# Data types:
#  V1                     object
# V2                     object
# V3                    float64
# V4                     object
# V5                    float64
# V6                    float64
# V7                    float64
# V8                    float64
# time           datetime64[ns]
# time_          datetime64[ns]
# date                   object
# source_file            object
# dtype: object

# %%
df_clean['date'] = pd.to_datetime(df_clean['date'], errors='coerce')

# %%
print("\nData types:\n", df_clean.dtypes)
# Out:
# Data types:
#  V1                     object
# V2                     object
# V3                    float64
# V4                     object
# V5                    float64
# V6                    float64
# V7                    float64
# V8                    float64
# time           datetime64[ns]
# time_          datetime64[ns]
# date           datetime64[ns]
# source_file            object
# dtype: object

# %%
df_clean
# Out:
#                     V1            V2       V3            V4            V5  \
# 0         CA0000001770  CA0000001582     98.0  P3:EE:H4:A11  1.488202e+09
# 5         CA0000001655  CA0000001770     87.0  P3:EE:H4:A11  1.488202e+09
# 10        CA0000001532  CA0000001601     28.0  P3:EE:H4:A11  1.488203e+09
# 13        CA0000001823  CA0000001770    150.0  P3:EE:H4:A11  1.488201e+09
# 23        CA0000001644  CA0000001655    146.0  P3:EE:H4:A11  1.488202e+09
# ...                ...           ...      ...           ...           ...
# 25195563  CA0000001783  CA0000001730    122.0   P3:EB:H1:A6  1.491731e+09
# 25195566  CA0000001783  CA0000001730   5340.0   P3:EB:H1:A6  1.491731e+09
# 25195567  CA0000001783  CA0000001978   3594.0   P3:EB:H1:A6  1.491731e+09
# 25195573  CA0000001783  CA0000001011  13624.0   P3:EB:H1:A6  1.491731e+09
# 25195579  CA0000002033  CA0000001783    754.0   P3:EB:H1:A6  1.491745e+09
#
#                     V6            V7            V8  \
# 0         1.488202e+09  1.488202e+09  1.488202e+09
# 5         1.488202e+09  1.488202e+09  1.488202e+09
# 10        1.488202e+09  1.488203e+09  1.488203e+09
# 13        1.488202e+09  1.488203e+09  1.488202e+09
# 23        1.488202e+09  1.488204e+09  1.488202e+09
# ...                ...           ...           ...
# 25195563  1.491732e+09  1.491746e+09  1.491732e+09
# 25195566  1.491732e+09  1.491746e+09  1.491737e+09
# 25195567  1.491735e+09  1.491746e+09  1.491738e+09
# 25195573  1.491731e+09  1.491746e+09  1.491745e+09
# 25195579  1.491731e+09  1.491746e+09  1.491746e+09
#
#                                   time               time_       date  \
# 0        1970-01-01 00:00:01.488201916 2017-02-27 03:25:16 2017-02-27
# 5        1970-01-01 00:00:01.488202069 2017-02-27 03:27:49 2017-02-27
# 10       1970-01-01 00:00:01.488202618 2017-02-27 03:36:58 2017-02-27
# 13       1970-01-01 00:00:01.488201992 2017-02-27 03:26:32 2017-02-27
# 23       1970-01-01 00:00:01.488202673 2017-02-27 03:37:53 2017-02-27
# ...                                ...                 ...        ...
# 25195563 1970-01-01 00:00:01.491734972 2017-04-09 00:49:32 2017-04-09
# 25195566 1970-01-01 00:00:01.491736401 2017-04-09 01:13:21 2017-04-09
# 25195567 1970-01-01 00:00:01.491737529 2017-04-09 01:32:09 2017-04-09
# 25195573 1970-01-01 00:00:01.491738286 2017-04-09 01:44:46 2017-04-09
# 25195579 1970-01-01 00:00:01.491742105 2017-04-09 02:48:25 2017-04-09
#
#                             source_file
# 0         14 2017-02-27 matrix2_res.csv
# 5         14 2017-02-27 matrix2_res.csv
# 10        14 2017-02-27 matrix2_res.csv
# 13        14 2017-02-27 matrix2_res.csv
# 23        14 2017-02-27 matrix2_res.csv
# ...                                 ...
# 25195563  54 2017-04-08 matrix2_res.csv
# 25195566  54 2017-04-08 matrix2_res.csv
# 25195567  54 2017-04-08 matrix2_res.csv
# 25195573  54 2017-04-08 matrix2_res.csv
# 25195579  54 2017-04-08 matrix2_res.csv
#
# [6298014 rows x 12 columns]

# %%
df_clean['V1'].nunique()
# Out:
# 1803

# %%
df_clean['V2'].nunique()
# Out:
# 1803

# %%
df_clean['date'].min()
# Out:
# Timestamp('2017-02-27 00:00:00')

# %%
df_clean['date'].max()
# Out:
# Timestamp('2017-04-09 00:00:00')

# %%
cleaned_data_path = '/content/drive/MyDrive/Hens Mobility/data/cleaned_combined_data.csv'
df_clean.to_csv(cleaned_data_path, index=False)

# %% [markdown]
# # Basic EDA

# %%
import seaborn as sns

# %%
print("Unique hens (V1):", df_clean['V1'].nunique())
print("Unique hens (V2):", df_clean['V2'].nunique())
print("Date range:", df_clean['date'].min(), "to", df_clean['date'].max())
# Out:
# Unique hens (V1): 1803
# Unique hens (V2): 1803
# Date range: 2017-02-27 00:00:00 to 2017-04-09 00:00:00

# %%
# Daily activity
daily_counts = df_clean.groupby('date').size()

# Plot
plt.figure(figsize=(12, 6))
daily_counts.plot(kind='line', color='skyblue', linewidth=2)
plt.title('Daily RFID Interactions')
plt.xlabel('Date')
plt.ylabel('Number of Interactions')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
# Hourly activity
df_clean['hour'] = df_clean['time'].dt.hour

# Count interactions per hour
hourly_counts = df_clean.groupby('hour').size()

# Plot
plt.figure(figsize=(10, 5))
hourly_counts.plot(kind='bar', color='coral')
plt.title('Average Hourly Activity of Hens')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Interactions')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
# Extract day of week
df_clean['day_of_week'] = df_clean['time'].dt.day_name()

# Heatmap: Hourly activity by day of week
heatmap_data = df_clean.groupby(['day_of_week', 'hour']).size().unstack(fill_value=0)

# Reorder days for better visualization
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
heatmap_data = heatmap_data.reindex(days_order)

# Fix: Fill NaNs with 0 before converting to int
heatmap_data = heatmap_data.fillna(0).astype(int)

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='d')
plt.title('Heatmap of Hen Activity by Hour and Day')
plt.ylabel('Day of Week')
plt.xlabel('Hour of Day')
plt.show()

# %% [markdown]
# # Contact Graph

# %%
# Build the Contact Graph
edge_list = df_clean[['V1', 'V2']].dropna()
G = nx.Graph()
G.add_edges_from(edge_list.itertuples(index=False, name=None))

# %%
print("Number of nodes (hens):", G.number_of_nodes())
print("Number of edges (contacts):", G.number_of_edges())
# Out:
# Number of nodes (hens): 1804
# Number of edges (contacts): 597047

# %%
# Visualize the Contact Graph
plt.figure(figsize=(12, 10))
pos = nx.spring_layout(G, seed=42, k=0.1)
nx.draw_networkx_nodes(G, pos, node_size=10, node_color='skyblue')
nx.draw_networkx_edges(G, pos, alpha=0.3)
plt.title("Hen Contact Graph")
plt.axis('off')
plt.show()

# %%
#Visualize with Community Detection
from networkx.algorithms import community

# Detect communities
communities = community.greedy_modularity_communities(G)
node_colors = {}
for i, com in enumerate(communities):
    for node in com:
        node_colors[node] = i

# Assign colors
colors = [node_colors[node] for node in G.nodes()]

plt.figure(figsize=(12, 10))
pos = nx.spring_layout(G, seed=42, k=0.1)
nx.draw_networkx_nodes(G, pos, node_size=10, node_color=colors, cmap=plt.cm.tab20)
nx.draw_networkx_edges(G, pos, alpha=0.2)
plt.title("Hen Contact Graph (Communities Colored)")
plt.axis('off')
plt.show()

# %%
# Top 100 nodes by degree
top_nodes = sorted(degrees.items(), key=lambda x: x[1], reverse=True)[:100]
top_nodes_list = [node for node, deg in top_nodes]
subgraph = G.subgraph(top_nodes_list)

plt.figure(figsize=(12, 10))
pos = nx.spring_layout(subgraph, seed=42, k=0.3)
nx.draw_networkx_nodes(subgraph, pos, node_size=100, node_color='skyblue')
nx.draw_networkx_edges(subgraph, pos, alpha=0.3)
plt.title("Top 100 Most Connected Hens")
plt.axis('off')
plt.show()

# %%
# Identify Top 5 Most Connected Hens
degree_centrality = nx.degree_centrality(G)
top_hens = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:5]

print("\nTop 5 Most Connected Hens:")
for hen, centrality in top_hens:
    print(f"Hen {hen}: Centrality {centrality:.4f}")
# Out:
# Top 5 Most Connected Hens:
# Hen CA0000001691: Centrality 0.8303
# Hen CA0000001528: Centrality 0.8292
# Hen CA0000001784: Centrality 0.8209
# Hen CA0000001404: Centrality 0.8109
# Hen CA0000000688: Centrality 0.8070

# %%
from networkx.algorithms import community

# Detect communities
communities = community.greedy_modularity_communities(G)

# Print number of communities and sizes
print("Number of communities:", len(communities))
for i, com in enumerate(communities[:5]):
    print(f"Community {i+1} size:", len(com))
# Out:
# Number of communities: 2
# Community 1 size: 1110
# Community 2 size: 694

# %%
nx.write_gexf(G, "/content/drive/MyDrive/Hens Mobility/data/hen_contact_graph.gexf")
print("Graph saved as GEXF for interactive exploration in Gephi/Cytoscape.")

# %% [markdown]
# # Temporal Graph Analysis

# %%
# Create daily graphs
daily_graphs = {}
for date, daily_data in df_clean.groupby('date'):
    daily_edges = daily_data[['V1', 'V2']].dropna()
    G_day = nx.Graph()
    G_day.add_edges_from(daily_edges.itertuples(index=False, name=None))
    daily_graphs[date] = G_day

print("Created daily graphs for", len(daily_graphs), "days")
# Out:
# Created daily graphs for 41 days

# %%
# Plot active hens per day
active_hens_per_day = {date: G_day.number_of_nodes() for date, G_day in daily_graphs.items()}
plt.figure(figsize=(12, 6))
plt.plot(list(active_hens_per_day.keys()), list(active_hens_per_day.values()), marker='o')
plt.title("Active Hens Per Day")
plt.xlabel("Date")
plt.ylabel("# of Active Hens")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
# Visualize sample daily graphs
sample_dates = list(daily_graphs.keys())[:3]  # first 3 days

for date in sample_dates:
    G_day = daily_graphs[date]
    plt.figure(figsize=(8, 6))
    pos = nx.spring_layout(G_day, seed=42, k=0.2)
    nx.draw_networkx_nodes(G_day, pos, node_size=10, node_color='skyblue')
    nx.draw_networkx_edges(G_day, pos, alpha=0.3)
    plt.title(f"Hen Contact Graph on {date.date()}")
    plt.axis('off')
    plt.show()

# %% [markdown]
# # Hen Behavior Analysis

# %%
#Visualize with Node Degrees (Size by Degree)
degrees = dict(G.degree())
node_sizes = [degrees[n] * 0.5 for n in G.nodes()]  # scale size down for clarity

plt.figure(figsize=(12, 10))
pos = nx.spring_layout(G, seed=42, k=0.1)
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color='skyblue', alpha=0.8)
nx.draw_networkx_edges(G, pos, alpha=0.2)
plt.title("Hen Contact Graph (Node Size by Degree)")
plt.axis('off')
plt.show()

# %%
# Explorers & stable hens
degrees = dict(G.degree())
avg_degree = sum(degrees.values()) / len(degrees)

# Explorers: degree much higher than average
explorers = [node for node, deg in degrees.items() if deg > avg_degree * 2]
# Stable hens: degree much lower than average
stable_hens = [node for node, deg in degrees.items() if deg < avg_degree * 0.5]

print("Explorers (highly connected):", explorers[:10])
print("Stable hens (few connections):", stable_hens[:10])
# Out:
# Explorers (highly connected): ['CA0000001410', 'CA0000001542', 'CA0000001762', 'CA0000002476', 'CA0000002132', 'CA0000002494', 'CA0000001697', 'CA0000001378', 'CA0000001689', 'CA0000001776']
# Stable hens (few connections): ['CA0000001392', 'CA0000000944', 'CA0000001683', 'CA0000001626', 'CA0000001414', 'CA0000001239', 'CA0000002421', 'CA0000001990', 'CA0000001589', 'CA0000002161']

# %%
# Hubs/leaders by betweenness centrality
bet_centrality = nx.betweenness_centrality(G)
top_leaders = sorted(bet_centrality.items(), key=lambda x: x[1], reverse=True)[:10]

print("Top 10 leader hens (by betweenness centrality):")
for hen, centrality in top_leaders:
    print(f"Hen {hen}: {centrality:.4f}")
# Out:
# Top 10 leader hens (by betweenness centrality):
# Hen CA0000001528: 0.0029
# Hen CA0000001691: 0.0028
# Hen CA0000001784: 0.0028
# Hen CA0000001646: 0.0025
# Hen CA0000001542: 0.0023
# Hen CA0000001888: 0.0023
# Hen CA0000001404: 0.0023
# Hen CA0000001378: 0.0023
# Hen CA0000001762: 0.0023
# Hen CA0000000688: 0.0022

# %%
# Degree distribution
degrees = dict(G.degree())
plt.figure(figsize=(10, 5))
plt.hist(list(degrees.values()), bins=50, color='skyblue', edgecolor='k')
plt.title("Degree Distribution of Hens")
plt.xlabel("Degree (# of connections)")
plt.ylabel("# of Hens")
plt.show()

# %%
centrality = nx.degree_centrality(G)
top_hens = sorted(centrality.items(), key=lambda x: x[1], reverse=True)[:10]
print("Top 10 central hens:", top_hens)
# Out:
# Top 10 central hens: [('CA0000001691', 0.8302828618968386), ('CA0000001528', 0.8291735995562951), ('CA0000001784', 0.8208541320022186), ('CA0000001404', 0.8108707709373267), ('CA0000000688', 0.8069883527454244), ('CA0000001378', 0.7936772046589019), ('CA0000002285', 0.7892401552967278), ('CA0000001742', 0.7864669994453689), ('CA0000001946', 0.7864669994453689), ('CA0000001403', 0.7809206877426512)]
